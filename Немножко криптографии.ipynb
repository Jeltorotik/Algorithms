# %% [markdown]
# # Немножко криптографии
#
#
# Во всех задачах по этой теме необходимо будет создать вначале шифровщик (encrypter) и дешифровщик (decrypter) какого-то конкретного метода.

# %% [markdown]
# 1. Начнем с самого простого - **шифр Цезаря (Caesar Cipher)**
#
# У вас есть некоторый алфавит (набор символов. Мы будем использовать английский алфавит). На вход шифровщика подается некоторый текст - сообщение, которое необходимо зашифровать (message), и число, характерезующее смещение (bias).
#
# Смысл метода состоит в том, чтобы все символы исходного сообщения сдвинуть по алфавиту на число bias.
#
#
# ![image.png](https://media.geeksforgeeks.org/wp-content/uploads/ceaserCipher.png)

# %%
# Caesar Cipher v1 goes here 
# Use regular string manupulations in a loop
alphabet_upper = string.ascii_lowercase
alphabet_lower = string.ascii_lowercase

def encrypt():
    pass

def decrypt():
    pass

# %%
# Caesar Cipher v2 goes here 
# Use build-in python function translate (and maketrans), avoid using loops
alphabet_upper = string.ascii_lowercase
alphabet_lower = string.ascii_lowercase

def encrypt():
    pass

def decrypt():
    pass

# %% [markdown]
# 2. Следующий несложный метод - **шифр Виженера (Vigenere Cipher)**
#
# Метод очень похож на предыдущий, но вместо простого алфавита использует таблицу алфавитов и кодовое слово (key).
#
# ![image.png](https://www.boxentriq.com/img/vigenere-table1.png)
#
# По столбцам мы двигаемся используя исходное сообщение, а по строчкам - используя ключ. Если ключ короче исходного сообщения, то его дублируют пока не получится строка такой же длины как и исходное сообщение

# %%
# Vigenère Cipher v1 goes here 
# Use regular string manupulations in loops
alphabet_upper = string.ascii_lowercase
alphabet_lower = string.ascii_lowercase

def encrypt():
    pass

def decrypt():
    pass

# %%
# Caesar Cipher v2 goes here 
# Use Caesar Cipher function you've made beforehand 
alphabet_upper = string.ascii_lowercase
alphabet_lower = string.ascii_lowercase

def encrypt():
    pass

def decrypt():
    pass

# %% [markdown]
# ## Список тем для самостояной работы и дальнейшего изучения
#
# 1. Шифр замены
# 2. Омофонический шифр
# 3. RSA шифрование
# 4. AES шифрование
# 5. Криптоанализ методом BruteForce (Шифр Цезаря)
# 6. Частотный криптоанализ
# 7. XOR шифрование
# 8. Шифр Вернама
#
# Обратить внимание стоит в первую очереь на **RSA** и **AES** шифрования. Они ширико используются в современных системах связи и передачи данных.
